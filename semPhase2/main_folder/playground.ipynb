# %%
import sys
sys.path.append('/Users/tjsss/Desktop/bharatAtomic')

# %%
import torch
from semPhase2.SAMmodel.sam2.sam2_image_predictor import SAM2ImagePredictor

predictor = SAM2ImagePredictor.from_pretrained("facebook/sam2-hiera-large")

with torch.inference_mode(), torch.autocast("cuda", dtype=torch.bfloat16):
    predictor.set_image('/Users/tjsss/Desktop/bharatAtomic/semPhase1/notebooks/images/Red-Velvet-Mite-SEM-Image.jpg')
    masks, _, _ = predictor.predict('hair')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import torch
# ----> 2 from semPhase2.SAMmodel.sam2.sam2_image_predictor import SAM2ImagePredictor
#       4 predictor = SAM2ImagePredictor.from_pretrained("facebook/sam2-hiera-large")
#       6 with torch.inference_mode(), torch.autocast("cuda", dtype=torch.bfloat16):
#
# ModuleNotFoundError: No module named 'semPhase2'
